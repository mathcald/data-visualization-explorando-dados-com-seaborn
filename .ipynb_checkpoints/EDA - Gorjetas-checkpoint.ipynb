# %% [markdown]
# # Importando base de dados

# %%
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv('dados/tips.csv')
df_traduzido = pd.read_csv('dados/gorjetas.csv')

# %%
df.head()
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   dessert     244 non-null    object
#  3   day         244 non-null    object
#  4   time        244 non-null    object
#  5   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 11.6+ KB

# %% [markdown]
# # Traduzindo as colunas e campos

# %%
# Conferindo as colunas
df.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {
    'total_bill': 'valor_da_conta',
    'tip': 'gorjeta', 
    'dessert': 'sobremesa', 
    'day': 'dia_da_semana', 
    'time': 'hora_do_dia', 
    'size': 'tota_de_pessoas'
}

# %%
df_gorjetas = df.rename(columns = renomear)

# %%
df_gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
# 1           10.34     1.66        No           Sun      Dinner
# 2           21.01     3.50        No           Sun      Dinner
# 3           23.68     3.31        No           Sun      Dinner
# 4           24.59     3.61        No           Sun      Dinner
#
#    tota_de_pessoas
# 0                2
# 1                3
# 2                3
# 3                2
# 4                4

# %%
df_gorjetas['dia_da_semana'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {
    'Sun': 'Domingo', 
    'Sat': 'Sábado', 
    'Thur': 'Quinta', 
    'Fri': 'Sexta'
}

# %%
df_gorjetas['dia_da_semana'] = df_gorjetas['dia_da_semana'].map(dias)

# %%
df_gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No       Domingo      Dinner
# 1           10.34     1.66        No       Domingo      Dinner
# 2           21.01     3.50        No       Domingo      Dinner
# 3           23.68     3.31        No       Domingo      Dinner
# 4           24.59     3.61        No       Domingo      Dinner
#
#    tota_de_pessoas
# 0                2
# 1                3
# 2                3
# 3                2
# 4                4

# %%
df_gorjetas['sobremesa'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {
    'No': 'Não', 
    'Yes': 'Sim'
}

# %%
df_gorjetas['sobremesa'] = df_gorjetas['sobremesa'].map(sim_nao)

# %%
df_gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Dinner
# 1           10.34     1.66       Não       Domingo      Dinner
# 2           21.01     3.50       Não       Domingo      Dinner
# 3           23.68     3.31       Não       Domingo      Dinner
# 4           24.59     3.61       Não       Domingo      Dinner
#
#    tota_de_pessoas
# 0                2
# 1                3
# 2                3
# 3                2
# 4                4

# %%
df_gorjetas['hora_do_dia'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {
    'Dinner': 'Jantar',
    'Lunch': 'Almoço'
}

# %%
df_gorjetas['hora_do_dia'] = df_gorjetas['hora_do_dia'].map(hora)

# %%
df_gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    tota_de_pessoas
# 0                2
# 1                3
# 2                3
# 3                2
# 4                4

# %%
df_gorjetas.to_csv('dados/gorjetas.csv', index=False)

# %% [markdown]
# ### Análise 1 - Valor da conta e gorjeta

# %%
df_traduzido.columns
# Out:
# Index(['valor_da_conta', 'gorjeta', 'sobremesa', 'dia_da_semana',
#        'hora_do_dia', 'tota_de_pessoas'],
#       dtype='object')

# %%
valor_gorjeta = sns.scatterplot(x='valor_da_conta', y='gorjeta', data=df_traduzido)

# %% [markdown]
# **Visualmente o valor da gorjeta aumenta conforme o valor da conta**

# %%
print(f'A base de dados possui {df_traduzido.shape[0]} registros')

print('\nRegistros não nulos:')
df_traduzido.count()
# Out:
# A base de dados possui 244 registros
#
# Registros não nulos:
# valor_da_conta     244
# gorjeta            244
# sobremesa          244
# dia_da_semana      244
# hora_do_dia        244
# tota_de_pessoas    244
# dtype: int64

# %% [markdown]
# #### Criando o campo porcentagem

# %%
 df_traduzido['porcentagem'] = df_traduzido['gorjeta'] / df_traduzido['valor_da_conta']

# %%
df_traduzido.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
#
#    tota_de_pessoas  porcentagem
# 0                2     0.059447

# %%
df_traduzido['porcentagem'] = df_traduzido['porcentagem'].round(2)

# %%
df_traduzido.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    tota_de_pessoas  porcentagem
# 0                2         0.06
# 1                3         0.16
# 2                3         0.17
# 3                2         0.14
# 4                4         0.15

# %%
porcentagem_conta = sns.scatterplot(x='valor_da_conta', y='porcentagem', data=df_traduzido)

# %% [markdown]
# **Visualmente, o valor da conta não é proporcinal ao valor da gorjeta**

# %%
porcentagem_conta_linha = sns.relplot(x='valor_da_conta', y='porcentagem', kind='line', data=df_traduzido)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', data=df_traduzido)

# %% [markdown]
# # Análise 2 - Sobremesas

# %%
df_traduzido[df_traduzido['sobremesa'] == 'Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  tota_de_pessoas  porcentagem
# count       93.000000  93.000000        93.000000    93.000000
# mean        20.756344   3.008710         2.408602     0.163226
# std          9.832154   1.401468         0.810751     0.085060
# min          3.070000   1.000000         1.000000     0.040000
# 25%         13.420000   2.000000         2.000000     0.110000
# 50%         17.920000   3.000000         2.000000     0.150000
# 75%         26.860000   3.680000         3.000000     0.200000
# max         50.810000  10.000000         5.000000     0.710000

# %%
df_traduzido[df_traduzido['sobremesa'] == 'Não'].describe()
# Out:
#        valor_da_conta     gorjeta  tota_de_pessoas  porcentagem
# count      151.000000  151.000000       151.000000   151.000000
# mean        19.188278    2.991854         2.668874     0.159536
# std          8.255582    1.377190         1.017984     0.039889
# min          7.250000    1.000000         1.000000     0.060000
# 25%         13.325000    2.000000         2.000000     0.140000
# 50%         17.590000    2.740000         2.000000     0.160000
# 75%         22.755000    3.505000         3.000000     0.185000
# max         48.330000    9.000000         6.000000     0.290000

# %%
sns.catplot(x='sobremesa', y='gorjeta', data=df_traduzido)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', col='sobremesa', data=df_traduzido)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=df_traduzido)

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=df_traduzido)

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', col='sobremesa', hue='sobremesa', data=df_traduzido)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', col='sobremesa', hue='sobremesa', data=df_traduzido)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', col='sobremesa',kind='line', hue='sobremesa', data=df_traduzido)

# %% [markdown]
# **Visualmente, existe uma diferença no valor da gorjeta daqueles que pediram sobremesa e não pediram sobremesa**

# %% [markdown]
# ## Teste de hipótese

# %%
from scipy.stats import ranksums

# %%
df_traduzido.query("sobremesa == 'Sim'").porcentagem
# Out:
# 56     0.08
# 58     0.16
# 60     0.16
# 61     0.14
# 62     0.18
#        ...
# 234    0.19
# 236    0.08
# 237    0.04
# 240    0.07
# 241    0.09
# Name: porcentagem, Length: 93, dtype: float64

# %%
sobremesa = df_traduzido.query("sobremesa == 'Sim'").porcentagem
sem_sobremesa = df_traduzido.query("sobremesa == 'Não'").porcentagem

# %%
r = ranksums(sobremesa, sem_sobremesa)
print('O valor do p-value é {}'.format(r.pvalue))
# Out:
# O valor do p-value é 0.5266635660124415

# %% [markdown]
# ## Analisando os dias da semana

# %%
df_traduzido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   valor_da_conta   244 non-null    float64
#  1   gorjeta          244 non-null    float64
#  2   sobremesa        244 non-null    object
#  3   dia_da_semana    244 non-null    object
#  4   hora_do_dia      244 non-null    object
#  5   tota_de_pessoas  244 non-null    int64
#  6   porcentagem      244 non-null    float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 13.5+ KB

# %%
df_traduzido.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
sns.catplot(x='dia_da_semana', y='valor_da_conta', data=df_traduzido)

# %% [markdown]
# **Visualmente o dia com menor movimento é a sexta-feira**

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', data=df_traduzido)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', data=df_traduzido)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', data=df_traduzido, col='dia_da_semana')

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', data=df_traduzido, col='dia_da_semana', palette='bright')

# %%
media_geral_gorjeta = df_traduzido['gorjeta'].mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [65], line 1
# ----> 1 media_geral_gorjeta = (df_traduzido['gorjeta'].mean()).round()
#
# AttributeError: 'float' object has no attribute 'round'

# %%
media_geral_gorjeta
# Out:
# 2.9982786885245902

# %%
df_traduzido.groupby(['dia_da_semana']).mean()
# Out:
#                valor_da_conta   gorjeta  tota_de_pessoas  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132         2.842105     0.166974
# Quinta              17.682742  2.771452         2.451613     0.161129
# Sexta               17.151579  2.734737         2.105263     0.169474
# Sábado              20.441379  2.993103         2.517241     0.153678
